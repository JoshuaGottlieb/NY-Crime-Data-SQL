# %% [markdown]
# ## Load Libraries and Data

# %%
import numpy as np
import pandas as pd

# %%
population_data_csv = '../data/raw/New_York_City_Population_by_Borough__1950_-_2040_20241014.csv'

# %%
df = pd.read_csv(population_data_csv)
df
# Out:
#           Age Group           Borough     1950  \
# 0  Total Population         NYC Total  7891957
# 1  Total Population             Bronx  1451277
# 2  Total Population          Brooklyn  2738175
# 3  Total Population         Manhattan  1960101
# 4  Total Population            Queens  1550849
# 5  Total Population     Staten Island   191555
#
#    1950 - Boro share of NYC total     1960  1960 - Boro share of NYC total  \
# 0                          100.00  7781984                          100.00
# 1                           18.39  1424815                           18.31
# 2                           34.70  2627319                           33.76
# 3                           24.84  1698281                           21.82
# 4                           19.65  1809578                           23.25
# 5                            2.43   221991                            2.85
#
#       1970  1970 - Boro share of NYC total     1980  \
# ...

# %%
# Drop first column and share of NYC total columns
df.drop(['Age Group'] + [x for x in df.columns if 'share' in x], axis = 1, inplace = True)

# %%
df
# Out:
#             Borough     1950     1960     1970     1980     1990     2000  \
# 0         NYC Total  7891957  7781984  7894862  7071639  7322564  8008278
# 1             Bronx  1451277  1424815  1471701  1168972  1203789  1332650
# 2          Brooklyn  2738175  2627319  2602012  2230936  2300664  2465326
# 3         Manhattan  1960101  1698281  1539233  1428285  1487536  1537195
# 4            Queens  1550849  1809578  1986473  1891325  1951598  2229379
# 5     Staten Island   191555   221991   295443   352121   378977   443728
#
#       2010     2020     2030     2040
# 0  8242624  8550971  8821027  9025145
# 1  1385108  1446788  1518998  1579245
# 2  2552911  2648452  2754009  2840525
# 3  1585873  1638281  1676720  1691617
# 4  2250002  2330295  2373551  2412649
# 5   468730   487155   497749   501109

# %%
# Write cleaned data to parquet file
df.to_parquet('../data/cleaned/population_data_cleaned.parquet.gz', index = False, compression = 'gzip')
